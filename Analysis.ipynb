# %%
import pandas as pd

df = pd.read_csv('latest_data//latestdata.csv')
df.head(10)
# Out:
# /Users/dineshmurali/miniconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (1,2,10,11,13,14,15,16,17,18,19,20,22,23,24,25,26,27,28,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        ID    age     sex              city          province        country  \
# 0     NaN    NaN     NaN               NaN               NaN            NaN
# 1  000-1-    NaN     NaN               NaN         Khuzestan           Iran
# 2  000-1-  60-69  female  Snohomish County        Washington  United States
# 3  000-1-    NaN     NaN               NaN               NaN            NaN
# 4  000-1-  50-59    male  Snohomish County        Washington  United States
# 5  000-1-  30-39  female  Snohomish County        Washington  United States
# 6  000-1-  30-39  female  Snohomish County        Washington  United States
# ...

# %%
df.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials',
#        'travel_history_binary'],
#       dtype='object')

# %%
df[df['country_new'] == 'United States']
# Out:
#                ID    age     sex                    city       province  \
# 2          000-1-  60-69  female        Snohomish County     Washington
# 4          000-1-  50-59    male        Snohomish County     Washington
# 5          000-1-  30-39  female        Snohomish County     Washington
# 6          000-1-  30-39  female        Snohomish County     Washington
# 11         000-1-  50-59    male        Snohomish County     Washington
# 13        000-1-1  60-69  female          Whatcom County     Washington
# 15       000-1-10  60-69  female           Pitkin County       Colorado
# 650    000-1-1052  20-29  female       Cumberland County          Maine
# 663    000-1-1053  20-29    male       Cumberland County          Maine
# 674    000-1-1054  50-59  female     Androscoggin County          Maine
# 686    000-1-1055  18-99    male       Rockingham County  New Hampshire
# 761    000-1-1061    NaN     NaN        Berkshire County  Massachusetts
# ...

# %%
usa = df[df['country_new'] == 'United States']
usa.shape
# Out:
# (6163, 34)

# %%
usa.dtypes
# Out:
# ID                           object
# age                          object
# sex                          object
# city                         object
# province                     object
# country                      object
# wuhan(0)_not_wuhan(1)       float64
# latitude                    float64
# longitude                   float64
# geo_resolution               object
# date_onset_symptoms          object
# date_admission_hospital      object
# date_confirmation            object
# symptoms                     object
# lives_in_Wuhan               object
# travel_history_dates         object
# travel_history_location      object
# reported_market_exposure     object
# additional_information       object
# chronic_disease_binary       object
# chronic_disease              object
# source                       object
# sequence_available           object
# outcome                      object
# date_death_or_discharge      object
# notes_for_discussion         object
# ...

# %%
usa['date_confirmation']
# Out:
# 2        11.03.2020
# 4        11.03.2020
# 5        11.03.2020
# 6        11.03.2020
# 11       11.03.2020
# 13       10.03.2020
# 15       11.03.2020
# 650      13.03.2020
# 663      13.03.2020
# 674      12.03.2020
# 686      12.03.2020
# 761      12.03.2020
# 772      12.03.2020
# 784      12.03.2020
# 797      12.03.2020
# 808      26.01.2020
# 809      12.03.2020
# 820      12.03.2020
# 821      26.01.2020
# 833      12.03.2020
# 845      12.03.2020
# 856      12.03.2020
# 871      12.03.2020
# 883      12.03.2020
# 895      12.03.2020
# 906      12.03.2020
# 919      12.03.2020
# 931      12.03.2020
# 943      12.03.2020
# 954      12.03.2020
#             ...
# 43388    15.03.2020
# 43399    15.03.2020
# 43412    15.03.2020
# 43423    15.03.2020
# 43435    15.03.2020
# 43447    15.03.2020
# 43459    15.03.2020
# 43472    15.03.2020
# 43485    15.03.2020
# 43497    15.03.2020
# 43510    15.03.2020
# 43521    15.03.2020
# 43534    15.03.2020
# 43546    15.03.2020
# ...

# %%
usa.fillna({'date_confirmation':'1.1.1753'}, inplace=True)
# Out:
# /Users/dineshmurali/miniconda3/lib/python3.5/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
pd.to_datetime(usa['date_confirmation'],format='%d.%m.%Y').max()
# Out:
# Timestamp('2020-03-20 00:00:00')

# %%
usa[usa['date_confirmation'] == '20.03.2020']
# Out:
#                 ID  age  sex city  province        country  \
# 35623  000-1-42751  NaN  NaN  NaN   Alabama  United States
# 35624  000-1-42752  NaN  NaN  NaN   Alabama  United States
# 35625  000-1-42753  NaN  NaN  NaN   Alabama  United States
# 35626  000-1-42754  NaN  NaN  NaN   Alabama  United States
# 35627  000-1-42755  NaN  NaN  NaN   Alabama  United States
# 35628  000-1-42756  NaN  NaN  NaN   Alabama  United States
# 35629  000-1-42757  NaN  NaN  NaN   Alabama  United States
# 35630  000-1-42758  NaN  NaN  NaN   Alabama  United States
# 35631  000-1-42759  NaN  NaN  NaN   Alabama  United States
# 35633  000-1-42760  NaN  NaN  NaN   Alabama  United States
# 35634  000-1-42761  NaN  NaN  NaN   Alabama  United States
# 35635  000-1-42762  NaN  NaN  NaN   Alabama  United States
# 35636  000-1-42763  NaN  NaN  NaN   Alabama  United States
# 35637  000-1-42764  NaN  NaN  NaN   Alabama  United States
# 35638  000-1-42765  NaN  NaN  NaN   Alabama  United States
# ...

# %%
usa[usa['symptoms'].notna()]['symptoms']
# Out:
# 4508                                  mild
# 11319    cough, fever, shortness of breath
# 11479    cough, fever, shortness of breath
# 15942                                 mild
# 15943                                 mild
# 17544                                 mild
# 38256                           runny nose
# 40212                 cough, fever, nausea
# 40595    cough, fever, shortness of breath
# 41965                                 mild
# 41972                                 mild
# 42282    fever, cough, shortness of breath
# Name: symptoms, dtype: object

# %%
usa[usa['admin1'] == 'Oregon'].shape
# Out:
# (68, 34)

# %%
usa[usa['admin1'] == 'Oregon'].shape
# Out:
# (68, 34)
